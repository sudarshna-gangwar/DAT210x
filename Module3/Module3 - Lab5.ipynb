# %% [markdown]
# # DAT210x - Programming with Python for DS

# %% [markdown]
# ## Module3 - Lab5

# %% [markdown]
# This code is intentionally missing! Read the directions on the course lab page!

# %%
# .. your code here ..

# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib

# This is new
# from pandas.tools.plotting import parallel_coordinates
from pandas.tools.plotting import andrews_curves

# %%
# Look pretty...

# matplotlib.style.use('ggplot')
plt.style.use('ggplot')

# %%
# .. your code here ..
df = pd.read_csv("/home/rk-ekincare/sudarshna/python_for_DS/DAT210x/Module3/Datasets/wheat.data")
# print df

# %%
# .. your code here ..
del df['id']
# del df['area']
# del df['perimeter']

# %%
# .. your code here ..
df.groupby('wheat_type')
# print df
plt.figure()
andrews_curves(df, 'wheat_type')
# Out:
# /home/rk-ekincare/anaconda2/lib/python2.7/site-packages/ipykernel_launcher.py:5: FutureWarning: 'pandas.tools.plotting.andrews_curves' is deprecated, import 'pandas.plotting.andrews_curves' instead.
#   """

# %%
# Display the graphs:
plt.show()
